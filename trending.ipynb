# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from pandas.io import sql
import snowflake.connector
import keyring
import psycopg2 
import time
from datetime import date, timedelta
from scipy import stats

pd.set_option('display.max_colwidth', 50)
pd.set_option('display.max_columns', 500)

from matplotlib import pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
sns.set_style("darkgrid")

# %%
snowflake_username = 'matthew.bessey@disneystreaming.com'

# %%
ctx = snowflake.connector.connect(authenticator='externalbrowser', 
                                  user=snowflake_username, 
                                  account='disneystreaming.us-east-1')
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...

# %%
query= """
select *
from
  (  
    (
    select 
      o.swid
      , o.swid_holdout
      , e.*
      from "DSS_PROD"."DSS"."SFMC_ACCOUNT_SWID_MAP" a
      join oneid_combined o on a.swid = o.swid
      join "DSS_PROD"."DISNEY_PLUS"."DIM_DISNEY_DAILY_ACCOUNT_ENGAGEMENT" e on a.account_id = e.account_id
      where e.ds = '2020-01-27'
    )
    union
    (
    select 
      o.swid
      , o.swid_holdout
      , e.*
      from "DSS_PROD"."DSS"."SFMC_ACCOUNT_SWID_MAP" a
      join oneid_combined o on a.swid = o.swid
      join "DSS_PROD"."DISNEY_PLUS"."DIM_DISNEY_DAILY_ACCOUNT_ENGAGEMENT" e on a.account_id = e.account_id
      where e.ds = '2020-02-02'
    )
  )
where account_id in
(
  select 
  distinct e.account_id
  from "DSS_PROD"."DISNEY_PLUS"."DIM_DISNEY_DAILY_ACCOUNT_ENGAGEMENT" e
  where e.ds = '2020-01-27'
  and e.is_pre_launch != '1'
  and e.account_home_country = 'US'
  and e.first_account_subscription_signup_date is not NULL
  and is_entitled = '1'
  limit 500000
)
and swid_holdout < '243'
;
"""

# %%
# run the query and write to engagement
engagement = pd.read_sql(query,ctx)

# %%
# map columns to lowercase
engagement.columns = engagement.columns.str.lower()

# %%
# create function and apply for mapping of holdout groups on 'swid_holdout'
def holdout_grouping(df):
    if df['swid_holdout'] >= 246:
        return "holdout"
    elif df['swid_holdout'] >= 197 and df['swid_holdout'] <= 246:
        return "trending holdout"
    else:
        return "exposed"
    
engagement['marketing_holdout'] = engagement.apply(holdout_grouping,axis=1)

# %%
#drop rows w/ no entitlement data, rewrite as int
engagement = engagement.drop(engagement[engagement['is_entitled']=='unknown'].index,axis=0)
engagement.is_entitled = engagement.is_entitled.astype(int)

# %%
pre = engagement[engagement['ds'] == date(2020,1,27)]
post = engagement[engagement['ds'] == date(2020,2,2)]

# %%
# remove unnecessary columns
columnsToRemove = ['swid','swid_holdout','ds','account_id','is_flagged','first_account_subscription_signup_week',
    'last_account_subscription_signup_week','is_entitled_l1','is_entitled_l7','is_entitled_l28','is_entitled_itd',
    'is_pre_launch','is_pre_launch_nltt','account_home_country','subscription_state_upd','subscription_type',
    'total_login_days_l1','total_login_days_l28','total_streams_l1','total_streams_l28','num_streaming_profiles_l1',
    'num_streaming_profiles_l28','num_general_streaming_profiles_l1','num_general_streaming_profiles_l28',
    'num_kids_streaming_profiles_l1','num_kids_streaming_profiles_l28','num_streaming_devices_l1','num_streaming_devices_l28',
    'account_total_stream_days_l1','account_total_stream_days_l28','account_profile_total_stream_days_l1',
    'account_profile_total_stream_days_l28','total_stream_days_general_profiles_l1','total_stream_days_general_profiles_l28',
    'total_stream_days_kids_profiles_l1','total_stream_days_kids_profiles_l28','total_stream_time_ms_l1','total_stream_time_ms_l28',
    'total_stream_time_general_profiles_ms_l1','total_stream_time_general_profiles_ms_l28','total_stream_time_kids_profiles_ms_l1',
    'total_stream_time_kids_profiles_ms_l28','total_stream_time_web_ms_l1','total_stream_time_web_ms_l28','total_stream_time_mobile_ms_l1',
    'total_stream_time_mobile_ms_l28','total_stream_time_connected_tv_ms_l1','total_stream_time_connected_tv_ms_l28',
    'total_stream_time_unknown_ms_l1','total_stream_time_unknown_ms_l28','last_stream_date','account_profile_total_stream_days_l7',
    'account_profile_total_stream_days_itd','total_stream_time_unknown_ms_l7','total_stream_time_unknown_ms_itd'
]

preCleaned = pre.drop(columnsToRemove,axis=1)
postCleaned = post.drop(columnsToRemove,axis=1)

# %%
renamedColumns = ['first_signup_date','last_signup_date', 'is_entitled','ttl_login_days_l7', 'ttl_login_days_itd', 'ttl_streams_l7',
    'ttl_streams_itd', 'streaming_profiles_l7','streaming_profiles_itd', 'general_streaming_profiles_l7','general_streaming_profiles_itd', 
    'kids_streaming_profiles_l7','kids_streaming_profiles_itd', 'streaming_devices_l7','streaming_devices_itd', 'ttl_stream_days_l7',
    'ttl_stream_days_itd','ttl_stream_days_general_profiles_l7','ttl_stream_days_general_profiles_itd','ttl_stream_days_kids_profiles_l7',
    'ttl_stream_days_kids_profiles_itd', 'ttl_stream_time_ms_l7','ttl_stream_time_ms_itd', 'ttl_stream_time_general_profiles_ms_l7',
    'ttl_stream_time_general_profiles_ms_itd','ttl_stream_time_kids_profiles_ms_l7','ttl_stream_time_kids_profiles_ms_itd', 
    'ttl_stream_time_web_ms_l7','ttl_stream_time_web_ms_itd', 'ttl_stream_time_mobile_ms_l7','ttl_stream_time_mobile_ms_itd',
    'ttl_stream_time_connected_tv_ms_l7','tl_stream_time_connected_tv_ms_itd', 'days_since_last_stream','marketing_holdout'
]

preCleaned.columns = renamedColumns
postCleaned.columns = renamedColumns

# %%
# define columns for binary construction
# binary = 1 if action occurred in interval, else 0

binaryConstructionList = [
    'ttl_login_days_l7','ttl_login_days_itd','ttl_streams_l7','ttl_streams_itd','general_streaming_profiles_l7', 
    'general_streaming_profiles_itd','kids_streaming_profiles_l7', 'kids_streaming_profiles_itd','ttl_stream_time_web_ms_l7',
    'ttl_stream_time_web_ms_itd','ttl_stream_time_mobile_ms_l7','ttl_stream_time_mobile_ms_itd', 'ttl_stream_time_connected_tv_ms_l7',
    'tl_stream_time_connected_tv_ms_itd','days_since_last_stream'
]

# %%
# create binary variables _bin
for i in binaryConstructionList:
    preCleaned[i + '_bin'] = preCleaned.apply(lambda df:
                                   1 if df[i] > 0
                                   else 0,
                                   axis=1)
    postCleaned[i + '_bin'] = postCleaned.apply(lambda df:
                                   1 if df[i] > 0
                                   else 0,
                                   axis=1)

# %%
preCleaned.groupby('marketing_holdout').mean()
# Out:
#                    is_entitled  ttl_login_days_l7  ttl_login_days_itd  \
# marketing_holdout
# exposed                    1.0           4.052727           41.568901
# trending holdout           1.0           4.050903           41.494255
#
#                    ttl_streams_l7  ttl_streams_itd  streaming_profiles_l7  \
# marketing_holdout
# exposed                 12.019507       148.566748               0.873262
# trending holdout        12.085874       149.467341               0.875235
#
#                    streaming_profiles_itd  general_streaming_profiles_l7  \
# marketing_holdout
# exposed                          1.774025                       0.825470
# trending holdout                 1.781146                       0.826666
#
#                    general_streaming_profiles_itd  kids_streaming_profiles_l7  \
# marketing_holdout
# exposed                                  1.684557                    0.048209
# trending holdout                         1.690615                    0.048943
#
#                    kids_streaming_profiles_itd  streaming_devices_l7  \
# marketing_holdout
# exposed                               0.100711              1.197484
# trending holdout                      0.101432              1.198502
#
#                    streaming_devices_itd  ttl_stream_days_l7  \
# marketing_holdout
# exposed                         3.855177            2.212080
# trending holdout                3.837103            2.224679
#
#                    ttl_stream_days_itd  ttl_stream_days_general_profiles_l7  \
# marketing_holdout
# exposed                      26.979651                             2.408623
# trending holdout             26.996362                             2.415282
#
#                    ttl_stream_days_general_profiles_itd  \
# marketing_holdout
# exposed                                       30.815455
# trending holdout                              30.805714
#
#                    ttl_stream_days_kids_profiles_l7  \
# marketing_holdout
# exposed                                    0.137585
# trending holdout                           0.141502
#
#                    ttl_stream_days_kids_profiles_itd  ttl_stream_time_ms_l7  \
# marketing_holdout
# exposed                                     1.375440           1.916347e+07
# trending holdout                            1.382068           1.923396e+07
#
#                    ttl_stream_time_ms_itd  \
# marketing_holdout
# exposed                      2.584057e+08
# trending holdout             2.592796e+08
#
#                    ttl_stream_time_general_profiles_ms_l7  \
# marketing_holdout
# exposed                                      1.826475e+07
# trending holdout                             1.828355e+07
#
#                    ttl_stream_time_general_profiles_ms_itd  \
# marketing_holdout
# exposed                                       2.489910e+08
# trending holdout                              2.496004e+08
#
#                    ttl_stream_time_kids_profiles_ms_l7  \
# marketing_holdout
# exposed                                  898727.980137
# trending holdout                         950404.554257
#
#                    ttl_stream_time_kids_profiles_ms_itd  \
# marketing_holdout
# exposed                                    9.414646e+06
# trending holdout                           9.679222e+06
#
#                    ttl_stream_time_web_ms_l7  ttl_stream_time_web_ms_itd  \
# marketing_holdout
# exposed                        798708.579846                1.225775e+07
# trending holdout               777658.559799                1.221870e+07
#
#                    ttl_stream_time_mobile_ms_l7  \
# marketing_holdout
# exposed                            4.169407e+06
# trending holdout                   4.166556e+06
#
#                    ttl_stream_time_mobile_ms_itd  \
# marketing_holdout
# exposed                             5.604367e+07
# trending holdout                    5.592744e+07
#
#                    ttl_stream_time_connected_tv_ms_l7  \
# marketing_holdout
# exposed                                  1.392768e+07
# trending holdout                         1.402382e+07
#
#                    tl_stream_time_connected_tv_ms_itd  days_since_last_stream  \
# marketing_holdout
# exposed                                  1.848073e+08                 8.20691
# trending holdout                         1.858150e+08                 8.19295
#
#                    ttl_login_days_l7_bin  ttl_login_days_itd_bin  \
# marketing_holdout
# exposed                         0.820559                1.000000
# trending holdout                0.820332                0.999989
#
#                    ttl_streams_l7_bin  ttl_streams_itd_bin  \
# marketing_holdout
# exposed                      0.639158             0.971168
# trending holdout             0.641094             0.971511
#
#                    general_streaming_profiles_l7_bin  \
# marketing_holdout
# exposed                                     0.629989
# trending holdout                            0.631326
#
#                    general_streaming_profiles_itd_bin  \
# marketing_holdout
# exposed                                      0.970729
# trending holdout                             0.970843
#
#                    kids_streaming_profiles_l7_bin  \
# marketing_holdout
# exposed                                  0.041658
# trending holdout                         0.042325
#
#                    kids_streaming_profiles_itd_bin  \
# marketing_holdout
# exposed                                   0.076870
# trending holdout                          0.077511
#
#                    ttl_stream_time_web_ms_l7_bin  \
# marketing_holdout
# exposed                                 0.062876
# trending holdout                        0.063119
#
#                    ttl_stream_time_web_ms_itd_bin  \
# marketing_holdout
# exposed                                  0.266016
# trending holdout                         0.263309
#
#                    ttl_stream_time_mobile_ms_l7_bin  \
# marketing_holdout
# exposed                                    0.293131
# trending holdout                           0.293645
#
#                    ttl_stream_time_mobile_ms_itd_bin  \
# marketing_holdout
# exposed                                     0.682124
# trending holdout                            0.681323
#
#                    ttl_stream_time_connected_tv_ms_l7_bin  \
# marketing_holdout
# exposed                                          0.488523
# trending holdout                                 0.488951
#
#                    tl_stream_time_connected_tv_ms_itd_bin  \
# marketing_holdout
# exposed                                          0.822099
# trending holdout                                 0.820842
#
#                    days_since_last_stream_bin
# marketing_holdout
# exposed                              0.676172
# trending holdout                     0.674671

# %%
postCleaned.groupby('marketing_holdout').mean()
# Out:
#                    is_entitled  ttl_login_days_l7  ttl_login_days_itd  \
# marketing_holdout
# exposed               0.981254           3.994616           44.995343
# trending holdout      0.981268           4.002901           44.926116
#
#                    ttl_streams_l7  ttl_streams_itd  streaming_profiles_l7  \
# marketing_holdout
# exposed                 11.258667       158.270203               0.846044
# trending holdout        11.395213       159.291741               0.848934
#
#                    streaming_profiles_itd  general_streaming_profiles_l7  \
# marketing_holdout
# exposed                          1.792218                       0.798654
# trending holdout                 1.799742                       0.801589
#
#                    general_streaming_profiles_itd  kids_streaming_profiles_l7  \
# marketing_holdout
# exposed                                  1.700851                    0.047816
# trending holdout                         1.707488                    0.047821
#
#                    kids_streaming_profiles_itd  streaming_devices_l7  \
# marketing_holdout
# exposed                               0.103258              1.159068
# trending holdout                      0.103891              1.161288
#
#                    streaming_devices_itd  ttl_stream_days_l7  \
# marketing_holdout
# exposed                         3.933396            2.139027
# trending holdout                3.915815            2.152517
#
#                    ttl_stream_days_itd  ttl_stream_days_general_profiles_l7  \
# marketing_holdout
# exposed                      28.824363                             2.318349
# trending holdout             28.852549                             2.332128
#
#                    ttl_stream_days_general_profiles_itd  \
# marketing_holdout
# exposed                                       32.814927
# trending holdout                              32.817782
#
#                    ttl_stream_days_kids_profiles_l7  \
# marketing_holdout
# exposed                                    0.135358
# trending holdout                           0.138023
#
#                    ttl_stream_days_kids_profiles_itd  ttl_stream_time_ms_l7  \
# marketing_holdout
# exposed                                      1.49462           1.790951e+07
# trending holdout                             1.50281           1.807969e+07
#
#                    ttl_stream_time_ms_itd  \
# marketing_holdout
# exposed                      2.739078e+08
# trending holdout             2.749366e+08
#
#                    ttl_stream_time_general_profiles_ms_l7  \
# marketing_holdout
# exposed                                      1.704619e+07
# trending holdout                             1.719027e+07
#
#                    ttl_stream_time_general_profiles_ms_itd  \
# marketing_holdout
# exposed                                       2.637304e+08
# trending holdout                              2.644744e+08
#
#                    ttl_stream_time_kids_profiles_ms_l7  \
# marketing_holdout
# exposed                                  863327.104257
# trending holdout                         889419.938830
#
#                    ttl_stream_time_kids_profiles_ms_itd  \
# marketing_holdout
# exposed                                    1.017740e+07
# trending holdout                           1.046212e+07
#
#                    ttl_stream_time_web_ms_l7  ttl_stream_time_web_ms_itd  \
# marketing_holdout
# exposed                        724963.652856                1.288490e+07
# trending holdout               713062.287752                1.283523e+07
#
#                    ttl_stream_time_mobile_ms_l7  \
# marketing_holdout
# exposed                            3.884849e+06
# trending holdout                   3.867951e+06
#
#                    ttl_stream_time_mobile_ms_itd  \
# marketing_holdout
# exposed                             5.938831e+07
# trending holdout                    5.926444e+07
#
#                    ttl_stream_time_connected_tv_ms_l7  \
# marketing_holdout
# exposed                                  1.304985e+07
# trending holdout                         1.323944e+07
#
#                    tl_stream_time_connected_tv_ms_itd  days_since_last_stream  \
# marketing_holdout
# exposed                                  1.961237e+08                9.189447
# trending holdout                         1.972937e+08                9.181887
#
#                    ttl_login_days_l7_bin  ttl_login_days_itd_bin  \
# marketing_holdout
# exposed                         0.803752                1.000000
# trending holdout                0.805170                0.999989
#
#                    ttl_streams_l7_bin  ttl_streams_itd_bin  \
# marketing_holdout
# exposed                      0.621287             0.973120
# trending holdout             0.622895             0.973721
#
#                    general_streaming_profiles_l7_bin  \
# marketing_holdout
# exposed                                     0.611827
# trending holdout                            0.613172
#
#                    general_streaming_profiles_itd_bin  \
# marketing_holdout
# exposed                                      0.972721
# trending holdout                             0.973075
#
#                    kids_streaming_profiles_l7_bin  \
# marketing_holdout
# exposed                                  0.041372
# trending holdout                         0.041384
#
#                    kids_streaming_profiles_itd_bin  \
# marketing_holdout
# exposed                                   0.078534
# trending holdout                          0.079142
#
#                    ttl_stream_time_web_ms_l7_bin  \
# marketing_holdout
# exposed                                 0.059056
# trending holdout                        0.058847
#
#                    ttl_stream_time_web_ms_itd_bin  \
# marketing_holdout
# exposed                                  0.270227
# trending holdout                         0.267582
#
#                    ttl_stream_time_mobile_ms_l7_bin  \
# marketing_holdout
# exposed                                    0.281928
# trending holdout                           0.283118
#
#                    ttl_stream_time_mobile_ms_itd_bin  \
# marketing_holdout
# exposed                                     0.688366
# trending holdout                            0.687510
#
#                    ttl_stream_time_connected_tv_ms_l7_bin  \
# marketing_holdout
# exposed                                          0.476096
# trending holdout                                 0.477993
#
#                    tl_stream_time_connected_tv_ms_itd_bin  \
# marketing_holdout
# exposed                                          0.826511
# trending holdout                                 0.825329
#
#                    days_since_last_stream_bin
# marketing_holdout
# exposed                              0.662197
# trending holdout                     0.664121

# %%
preTrending = preCleaned[preCleaned['marketing_holdout'] == 'exposed']
preHoldout = preCleaned[preCleaned['marketing_holdout'] == 'trending holdout']
postTrending = postCleaned[postCleaned['marketing_holdout'] == 'exposed']
postHoldout = postCleaned[postCleaned['marketing_holdout'] == 'trending holdout']

# %%
test_columns = [
    'is_entitled','ttl_login_days_l7', 'ttl_login_days_itd', 'ttl_streams_l7','ttl_streams_itd',
    'streaming_profiles_l7', 'streaming_profiles_itd','general_streaming_profiles_l7', 'general_streaming_profiles_itd',
    'kids_streaming_profiles_l7', 'kids_streaming_profiles_itd','streaming_devices_l7', 'streaming_devices_itd', 'ttl_stream_days_l7',
    'ttl_stream_days_itd', 'ttl_stream_days_general_profiles_l7','ttl_stream_days_general_profiles_itd','ttl_stream_days_kids_profiles_l7', 
    'ttl_stream_days_kids_profiles_itd','ttl_stream_time_ms_l7', 'ttl_stream_time_ms_itd','ttl_stream_time_general_profiles_ms_l7',
    'ttl_stream_time_general_profiles_ms_itd','ttl_stream_time_kids_profiles_ms_l7','ttl_stream_time_kids_profiles_ms_itd', 
    'ttl_stream_time_web_ms_l7','ttl_stream_time_web_ms_itd', 'ttl_stream_time_mobile_ms_l7','ttl_stream_time_mobile_ms_itd', 
    'ttl_stream_time_connected_tv_ms_l7','tl_stream_time_connected_tv_ms_itd','days_since_last_stream','ttl_login_days_l7_bin', 
    'ttl_login_days_itd_bin','ttl_streams_l7_bin','ttl_streams_itd_bin','general_streaming_profiles_l7_bin',
    'general_streaming_profiles_itd_bin','kids_streaming_profiles_l7_bin','kids_streaming_profiles_itd_bin', 'ttl_stream_time_web_ms_l7_bin',
    'ttl_stream_time_web_ms_itd_bin', 'ttl_stream_time_mobile_ms_l7_bin','ttl_stream_time_mobile_ms_itd_bin',
    'ttl_stream_time_connected_tv_ms_l7_bin','tl_stream_time_connected_tv_ms_itd_bin', 'days_since_last_stream_bin'
]

# %%
def run_p_test(exposed,holdout,test_columns):
    p_values = pd.DataFrame(columns=['p','diff','exposed_mean','holdout_mean'])

    for i in test_columns:
        try: 
            p1 = stats.ttest_ind(exposed[i], holdout[i])[1]
            try:
                diff = (exposed[i].mean()/holdout[i].mean()-1)*100
                exposed_mean = exposed[i].mean()
                holdout_mean = holdout[i].mean()
            except (ZeroDivisionError):
                diff = "Undefined"
                marketing_mean = "Undefined"
                holdout_mean = "Undefined"
        except (TypeError,RuntimeWarning): 
            p1 = "Broke!"
        mydict = {'name':i,'p':p1,'diff':diff,'exposed_mean':exposed_mean,'holdout_mean':holdout_mean}
        series = pd.Series(mydict)
        p_values = p_values.append(mydict,ignore_index=True)
        #print("Completed",i)

    p_values = p_values.set_index('name')
    return p_values

# %%
p_values1 = run_p_test(postTrending,postHoldout,test_columns)

# %%
p_values1
# Out:
#                                                 p      diff  exposed_mean  \
# name
# is_entitled                              0.481829 -0.294974  7.901958e-01
# ttl_login_days_l7                        0.097592 -1.166632  3.383234e+00
# ttl_login_days_itd                       0.039276 -1.109683  4.056307e+01
# ttl_streams_l7                           0.402800 -1.513071  9.056352e+00
# ttl_streams_itd                          0.380873 -1.030026  1.377003e+02
# streaming_profiles_l7                    0.627032 -0.497277  6.866790e-01
# streaming_profiles_itd                   0.704971 -0.253327  1.675159e+00
# general_streaming_profiles_l7            0.854581 -0.185998  6.494823e-01
# general_streaming_profiles_itd           0.781289 -0.180749  1.598592e+00
# kids_streaming_profiles_l7               0.223395 -5.497069  3.755452e-02
# kids_streaming_profiles_itd              0.689262 -1.355419  8.715882e-02
# streaming_devices_l7                     0.912151  0.121777  9.419383e-01
# streaming_devices_itd                    0.357814 -0.676601  3.583281e+00
# ttl_stream_days_l7                       0.464964 -0.777923  1.723982e+00
# ttl_stream_days_itd                      0.121677 -1.051160  2.513519e+01
# ttl_stream_days_general_profiles_l7      0.785309 -0.328047  1.874133e+00
# ttl_stream_days_general_profiles_itd     0.386558 -0.708859  2.860782e+01
# ttl_stream_days_kids_profiles_l7         0.774333 -1.547451  1.082625e-01
# ttl_stream_days_kids_profiles_itd        0.246263 -5.033936  1.215862e+00
# ttl_stream_time_ms_l7                    0.442299 -1.256089  1.440995e+07
# ttl_stream_time_ms_itd                   0.303661 -1.090673  2.376458e+08
# ttl_stream_time_general_profiles_ms_l7   0.574094 -0.935809  1.371086e+07
# ttl_stream_time_general_profiles_ms_itd  0.459342 -0.788476  2.294245e+08
# ttl_stream_time_kids_profiles_ms_l7      0.307839 -7.143916  6.990914e+05
# ttl_stream_time_kids_profiles_ms_itd     0.097887 -8.839508  8.221254e+06
# ttl_stream_time_web_ms_l7                0.605371 -3.363561  5.816003e+05
# ttl_stream_time_web_ms_itd               0.133523 -4.854816  1.127382e+07
# ttl_stream_time_mobile_ms_l7             0.272190 -3.185722  3.160963e+06
# ttl_stream_time_mobile_ms_itd            0.159087 -2.499310  5.216669e+07
# ttl_stream_time_connected_tv_ms_l7       0.695107 -0.750603  1.044840e+07
# tl_stream_time_connected_tv_ms_itd       0.705057 -0.479158  1.692820e+08
# days_since_last_stream                        NaN  0.159376  1.726184e+01
# ttl_login_days_l7_bin                    0.546796 -0.330285  6.879913e-01
# ttl_login_days_itd_bin                        NaN  0.000000  1.000000e+00
# ttl_streams_l7_bin                       0.350501 -0.753004  5.026313e-01
# ttl_streams_itd_bin                      0.021393 -0.372591  9.612657e-01
# general_streaming_profiles_l7_bin        0.444282 -0.626450  4.956719e-01
# general_streaming_profiles_itd_bin       0.020499 -0.377846  9.607354e-01
# kids_streaming_profiles_l7_bin           0.068931 -7.578438  3.227859e-02
# kids_streaming_profiles_itd_bin          0.322275 -2.945033  6.665164e-02
# ttl_stream_time_web_ms_l7_bin            0.520033 -2.299095  4.770868e-02
# ttl_stream_time_web_ms_itd_bin           0.288420 -1.482952  2.495990e-01
# ttl_stream_time_mobile_ms_l7_bin         0.850226  0.282799  2.302584e-01
# ttl_stream_time_mobile_ms_itd_bin        0.257894 -0.652194  6.644087e-01
# ttl_stream_time_connected_tv_ms_l7_bin   0.276214 -1.112290  3.849835e-01
# tl_stream_time_connected_tv_ms_itd_bin   0.765661 -0.129503  7.789546e-01
# days_since_last_stream_bin               0.108614 -0.793495  7.281440e-01
#
#                                          holdout_mean
# name
# is_entitled                              7.925336e-01
# ttl_login_days_l7                        3.423169e+00
# ttl_login_days_itd                       4.101824e+01
# ttl_streams_l7                           9.195486e+00
# ttl_streams_itd                          1.391334e+02
# streaming_profiles_l7                    6.901107e-01
# streaming_profiles_itd                   1.679414e+00
# general_streaming_profiles_l7            6.506926e-01
# general_streaming_profiles_itd           1.601487e+00
# kids_streaming_profiles_l7               3.973900e-02
# kids_streaming_profiles_itd              8.835642e-02
# streaming_devices_l7                     9.407926e-01
# streaming_devices_itd                    3.607691e+00
# ttl_stream_days_l7                       1.737498e+00
# ttl_stream_days_itd                      2.540220e+01
# ttl_stream_days_general_profiles_l7      1.880302e+00
# ttl_stream_days_general_profiles_itd     2.881206e+01
# ttl_stream_days_kids_profiles_l7         1.099642e-01
# ttl_stream_days_kids_profiles_itd        1.280312e+00
# ttl_stream_time_ms_l7                    1.459325e+07
# ttl_stream_time_ms_itd                   2.402663e+08
# ttl_stream_time_general_profiles_ms_l7   1.384038e+07
# ttl_stream_time_general_profiles_ms_itd  2.312478e+08
# ttl_stream_time_kids_profiles_ms_l7      7.528762e+05
# ttl_stream_time_kids_profiles_ms_itd     9.018439e+06
# ttl_stream_time_web_ms_l7                6.018437e+05
# ttl_stream_time_web_ms_itd               1.184907e+07
# ttl_stream_time_mobile_ms_l7             3.264976e+06
# ttl_stream_time_mobile_ms_itd            5.350392e+07
# ttl_stream_time_connected_tv_ms_l7       1.052742e+07
# tl_stream_time_connected_tv_ms_itd       1.700970e+08
# days_since_last_stream                   1.723437e+01
# ttl_login_days_l7_bin                    6.902712e-01
# ttl_login_days_itd_bin                   1.000000e+00
# ttl_streams_l7_bin                       5.064449e-01
# ttl_streams_itd_bin                      9.648607e-01
# general_streaming_profiles_l7_bin        4.987966e-01
# general_streaming_profiles_itd_bin       9.643793e-01
# kids_streaming_profiles_l7_bin           3.492539e-02
# kids_streaming_profiles_itd_bin          6.867412e-02
# ttl_stream_time_web_ms_l7_bin            4.883136e-02
# ttl_stream_time_web_ms_itd_bin           2.533562e-01
# ttl_stream_time_mobile_ms_l7_bin         2.296090e-01
# ttl_stream_time_mobile_ms_itd_bin        6.687704e-01
# ttl_stream_time_connected_tv_ms_l7_bin   3.893138e-01
# tl_stream_time_connected_tv_ms_itd_bin   7.799647e-01
# days_since_last_stream_bin               7.339680e-01
